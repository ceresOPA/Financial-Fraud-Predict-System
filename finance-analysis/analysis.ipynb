# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Unnamed: 0  loan_amnt  term  int_rate  grade  home_ownership  emp_length  \
# 0           0    18500.0    36     13.58      5               1           6
# 1           1     7000.0    36      7.34      7               1          10
# 2           2    16000.0    60     11.98      6               1           5
# 3           3    28000.0    36     10.90      6               1           6
# 4           4     8300.0    36      7.34      7               1           4
#
#    label  Cash  DirectPay
# 0      0     1          0
# 1      0     1          0
# 2      0     1          0
# 3      0     1          0
# 4      0     1          0

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df.head()
# Out:
#    loan_amnt  term  int_rate  grade  home_ownership  emp_length  label  Cash  \
# 0    18500.0    36     13.58      5               1           6      0     1
# 1     7000.0    36      7.34      7               1          10      0     1
# 2    16000.0    60     11.98      6               1           5      0     1
# 3    28000.0    36     10.90      6               1           6      0     1
# 4     8300.0    36      7.34      7               1           4      0     1
#
#    DirectPay
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.drop(["label","Cash","DirectPay"],axis=1,inplace=True)
df.head()
# Out:
#    loan_amnt  term  int_rate  grade  home_ownership  emp_length
# 0    18500.0    36     13.58      5               1           6
# 1     7000.0    36      7.34      7               1          10
# 2    16000.0    60     11.98      6               1           5
# 3    28000.0    36     10.90      6               1           6
# 4     8300.0    36      7.34      7               1           4

# %%
df.to_csv("test.csv")

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#    Unnamed: 0  loan_amnt  term  int_rate  grade  home_ownership  emp_length
# 0           0    18500.0    36     13.58      5               1           6
# 1           1     7000.0    36      7.34      7               1          10
# 2           2    16000.0    60     11.98      6               1           5
# 3           3    28000.0    36     10.90      6               1           6
# 4           4     8300.0    36      7.34      7               1           4

# %%
"Unnamed: 0" in test.columns
# Out:
# True

# %%
test.drop("Unnamed: 0",axis=1,inplace=True)
test.head()
# Out:
#    loan_amnt  term  int_rate  grade  home_ownership  emp_length
# 0    18500.0    36     13.58      5               1           6
# 1     7000.0    36      7.34      7               1          10
# 2    16000.0    60     11.98      6               1           5
# 3    28000.0    36     10.90      6               1           6
# 4     8300.0    36      7.34      7               1           4

# %%
test[test['loan_amnt']<3000].shape[0]
# Out:
# 179

# %%
test[test['grade']==7].shape[0]
# Out:
# 819
